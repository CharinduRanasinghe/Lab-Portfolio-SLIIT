# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
   
image = cv2.imread('C:\\Users\\chari\\OneDrive\\Documents\\Sliit\\Y3S1\\DIP\\Lab 1\\test.jpg')
   
c = 255 / np.log(1 + np.max(image))
log_image = c * (np.log(image + 1))
   
log_image = np.array(log_image, dtype = np.uint8)
   
# Display original
plt.imshow(image)
plt.show()
# Display transformed
plt.imshow(log_image)
plt.show()
# Out:
# C:\Users\chari\AppData\Local\Temp\ipykernel_25040\3300069650.py:8: RuntimeWarning: divide by zero encountered in log
#   log_image = c * (np.log(image + 1))
# C:\Users\chari\AppData\Local\Temp\ipykernel_25040\3300069650.py:10: RuntimeWarning: invalid value encountered in cast
#   log_image = np.array(log_image, dtype = np.uint8)

# %%
import cv2
import numpy as np
  

img = cv2.imread('C:\\Users\\chari\\OneDrive\\Documents\\Sliit\\Y3S1\\DIP\\Lab 1\\test.jpg')
  
for gamma in [0.1, 0.5, 1.2, 2.2]:
    
    gamma_transformed = np.array(255*(img / 255) ** gamma, dtype = 'uint8')
    #Display transformed
    plt.imshow(gamma_transformed)
    plt.show()

# %%
import cv2
import numpy as np
  

def pixelVal(pix, r1, s1, r2, s2):
    if (0 <= pix and pix <= r1):
        return (s1 / r1)*pix
    elif (r1 < pix and pix <= r2):
        return ((s2 - s1)/(r2 - r1)) * (pix - r1) + s1
    else:
        return ((255 - s2)/(255 - r2)) * (pix - r2) + s2
  
 # Open the image.
img = cv2.imread('C:\\Users\\chari\\OneDrive\\Documents\\Sliit\\Y3S1\\DIP\\Lab 1\\test.jpg')
  
# Define parameters.
r1 = 70
s1 = 0
r2 = 140
s2 = 255
  

pixel_vec = np.vectorize(pixelVal)
  

contrast_stretched = pixel_vec(img, r1, s1, r2, s2)

plt.imshow(img)
plt.show()

#DIsplay contrast stretched image
plt.imshow(gamma_transformed)
plt.show()
